# %% [markdown]
# <a href="https://colab.research.google.com/github/AnnayanB/DataScienceCapstoneProjects/blob/main/EDA_Project/TelecomChurn_Annayan(Milan).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Orange S.A., formerly France Télécom S.A., is a French multinational telecommunications corporation. The Orange Telecom's Churn Dataset, consists of cleaned customer activity data (features), along with a churn label specifying whether a customer canceled the subscription.
# Explore and analyze the data to discover key factors responsible for customer churn and come up with ways/recommendations to ensure customer retention.**

# %% [markdown]
# **Column Overview:**
#
# **State**: the state in which the customer resides, indicated by a two-letter abbreviation
#
# **Account Length**: the number of days that this account has been active
#
# **Area Code**: the three-digit area code of the corresponding customer’s phone number
#
# **Int’l Plan**: whether the customer has an international calling plan: yes/no
#
# **VMail Plan**: whether the customer has a voice mail feature: yes/no
#
# **VMail Message**: presumably the average number of voice mail messages per month
#
# **Day Mins**: the total number of calling minutes used during the day
#
# **Day Calls**: the total number of calls placed during the day
#
# **Day Charge**: the billed cost of daytime calls
#
# **Eve Mins**: the total number of calling minutes used during the evening
#
# **Eve Calls**: the total number of calls placed during the evening
#
# **Eve Charge**: the billed cost of evening time calls
#
# **Night Mins**: the total number of calling minutes used during the night
#
# **Night Calls**: the total number of calls placed during the night
#
# **Night Charge**: the billed cost of nighttime calls
#
# **Intl Mins**: the total number of international minutes
#
# **Intl Calls**: the total number of international calls
#
# **Intl Charge**: the billed cost for international calls
#
# **CustServ Calls**: the number of calls placed to Customer Service
#
# **Churn?**: whether the customer left the service: true/false

# %%
import numpy as np 
import pandas as pd
import matplotlib.pyplot as plt
# %lsmagic
# %matplotlib inline
import seaborn as sns

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
filepath= '/content/drive/MyDrive/Almabetter_Capstone/TelecomChurnAnalysis_Annayan/Telecom Churn.csv'

telecom_df = pd.read_csv(filepath)

# %%
telecom_df.shape
# Out:
# (3333, 20)

# %% [markdown]
# **Checking the columns present in our dataset**

# %%
telecom_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3333 entries, 0 to 3332
# Data columns (total 20 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   State                   3333 non-null   object
#  1   Account length          3333 non-null   int64
#  2   Area code               3333 non-null   int64
#  3   International plan      3333 non-null   object
#  4   Voice mail plan         3333 non-null   object
#  5   Number vmail messages   3333 non-null   int64
#  6   Total day minutes       3333 non-null   float64
#  7   Total day calls         3333 non-null   int64
#  8   Total day charge        3333 non-null   float64
#  9   Total eve minutes       3333 non-null   float64
#  10  Total eve calls         3333 non-null   int64
#  11  Total eve charge        3333 non-null   float64
#  12  Total night minutes     3333 non-null   float64
#  13  Total night calls       3333 non-null   int64
# ...

# %% [markdown]
# **Checking if we have null in our dataset**

# %%
telecom_df.isna().sum()
# Out:
# State                     0
# Account length            0
# Area code                 0
# International plan        0
# Voice mail plan           0
# Number vmail messages     0
# Total day minutes         0
# Total day calls           0
# Total day charge          0
# Total eve minutes         0
# Total eve calls           0
# Total eve charge          0
# Total night minutes       0
# Total night calls         0
# Total night charge        0
# Total intl minutes        0
# Total intl calls          0
# Total intl charge         0
# Customer service calls    0
# Churn                     0
# dtype: int64

# %% [markdown]
# **Checking unique values in each columns**

# %%
telecom_df.nunique()
# Out:
# State                       51
# Account length             212
# Area code                    3
# International plan           2
# Voice mail plan              2
# Number vmail messages       46
# Total day minutes         1667
# Total day calls            119
# Total day charge          1667
# Total eve minutes         1611
# Total eve calls            123
# Total eve charge          1440
# Total night minutes       1591
# Total night calls          120
# Total night charge         933
# Total intl minutes         162
# Total intl calls            21
# Total intl charge          162
# Customer service calls      10
# Churn                        2
# dtype: int64

# %%
#Fetching first 5 rows of dataframe
telecom_df.head()
# Out:
#   State  Account length  Area code International plan Voice mail plan  \
# 0    KS             128        415                 No             Yes
# 1    OH             107        415                 No             Yes
# 2    NJ             137        415                 No              No
# 3    OH              84        408                Yes              No
# 4    OK              75        415                Yes              No
#
#    Number vmail messages  Total day minutes  Total day calls  \
# 0                     25              265.1              110
# 1                     26              161.6              123
# 2                      0              243.4              114
# 3                      0              299.4               71
# 4                      0              166.7              113
#
#    Total day charge  Total eve minutes  Total eve calls  Total eve charge  \
# 0             45.07              197.4               99             16.78
# ...

# %%
#Fetching last 5 rows of dataframe
telecom_df.tail()
# Out:
#      State  Account length  Area code International plan Voice mail plan  \
# 3328    AZ             192        415                 No             Yes
# 3329    WV              68        415                 No              No
# 3330    RI              28        510                 No              No
# 3331    CT             184        510                Yes              No
# 3332    TN              74        415                 No             Yes
#
#       Number vmail messages  Total day minutes  Total day calls  \
# 3328                     36              156.2               77
# 3329                      0              231.1               57
# 3330                      0              180.8              109
# 3331                      0              213.8              105
# 3332                     25              234.4              113
#
#       Total day charge  Total eve minutes  Total eve calls  Total eve charge  \
# ...

# %%
# Checking the stats of our numerical columns
telecom_df.describe()
# Out:
#        Account length    Area code  Number vmail messages  Total day minutes  \
# count     3333.000000  3333.000000            3333.000000        3333.000000
# mean       101.064806   437.182418               8.099010         179.775098
# std         39.822106    42.371290              13.688365          54.467389
# min          1.000000   408.000000               0.000000           0.000000
# 25%         74.000000   408.000000               0.000000         143.700000
# 50%        101.000000   415.000000               0.000000         179.400000
# 75%        127.000000   510.000000              20.000000         216.400000
# max        243.000000   510.000000              51.000000         350.800000
#
#        Total day calls  Total day charge  Total eve minutes  Total eve calls  \
# count      3333.000000       3333.000000        3333.000000      3333.000000
# mean        100.435644         30.562307         200.980348       100.114311
# ...

# %% [markdown]
# **First Objective: Exploit the 'Account length' column to see if we can get any insight regarding customer retention.**

# %%
# Extract the top ten account length.
telecom_df.sort_values('Account length').tail(10)
# Out:
#      State  Account length  Area code International plan Voice mail plan  \
# 238     WY             215        510                 No              No
# 1045    TX             217        408                 No              No
# 2277    DC             217        415                 No              No
# 3216    SD             221        510                 No             Yes
# 416     DE             224        510                Yes              No
# 1886    ID             224        510                 No              No
# 1751    WY             225        415                 No              No
# 1551    MI             225        415                 No              No
# 1408    NM             232        408                 No              No
# 817     UT             243        510                 No              No
#
#       Number vmail messages  Total day minutes  Total day calls  \
# 238                       0               83.6              148
# ...

# %% [markdown]
# Observations:
#
#
#
# *   Above dataframe shows us the top ten account length and its corresponding
#     values.
#
#
# *   Only two people are getting churned.
#
#
# *   First person to get churned ( row index - 416 ) had opted for the
#     international plan made one customer service. His day
#     calling charge was significantly high as well.
#
#
#
#
# *   Second person to get churned ( row index - 1551 ) didn't opt for any add on services and didn't
#     make any customer service call. But the day calling charge is significantly
#     high.
#
#
# *   Generally people who are not getting churned are having less day calling
#     minutes as compared to both evening and night calling minutes.

# %%
#Account length vs Churn
top_ten_acc_len = telecom_df.groupby(['Account length','Churn'])['Churn'].count().unstack(level=-1).tail(30)
top_ten_acc_len
# Out:
# Churn           False  True
# Account length
# 184               3.0   1.0
# 185               6.0   NaN
# 186               2.0   NaN
# 188               NaN   1.0
# 189               6.0   NaN
# 190               7.0   NaN
# 191               1.0   NaN
# 192               3.0   NaN
# 193               3.0   1.0
# 194               3.0   NaN
# 195               2.0   NaN
# 196               2.0   NaN
# 197               2.0   1.0
# 199               1.0   NaN
# 200               1.0   NaN
# 201               2.0   1.0
# 202               1.0   NaN
# 204               2.0   NaN
# 205               2.0   NaN
# 208               NaN   1.0
# 209               2.0   1.0
# 210               2.0   NaN
# 212               1.0   1.0
# 215               1.0   NaN
# 217               2.0   NaN
# 221               1.0   NaN
# 224               1.0   1.0
# 225               1.0   1.0
# 232               1.0   NaN
# 243               1.0   NaN

# %%
plot = top_ten_acc_len.plot.bar(figsize=(20, 11))

# %%
bottom_ten_acc_len = telecom_df.groupby(['Account length','Churn'])['Churn'].count().unstack(level=-1).head(30)
bottom_ten_acc_len
# Out:
# Churn           False  True
# Account length
# 1                 7.0   1.0
# 2                 NaN   1.0
# 3                 5.0   NaN
# 4                 1.0   NaN
# 5                 1.0   NaN
# 6                 2.0   NaN
# 7                 2.0   NaN
# 8                 1.0   NaN
# 9                 3.0   NaN
# 10                3.0   NaN
# 11                4.0   NaN
# 12                2.0   1.0
# 13                8.0   1.0
# 15                3.0   NaN
# 16                7.0   1.0
# 17                2.0   2.0
# 18                2.0   NaN
# 19                4.0   1.0
# 20                3.0   NaN
# 21                7.0   1.0
# 22                6.0   NaN
# 23                2.0   2.0
# 24                5.0   3.0
# 25                4.0   1.0
# 26                1.0   NaN
# 27                8.0   1.0
# 28                5.0   1.0
# 29                4.0   1.0
# 30                8.0   NaN
# 31                7.0   NaN

# %%
plot = bottom_ten_acc_len.plot.bar(figsize=(20, 11))

# %% [markdown]
# **Churning is high during the initial 30 days.**

# %%
# Now we will draw a random plot to see the range of the account length in which maximum number of customers are retained
df1 = telecom_df.groupby(['Account length','Churn'])['Churn'].count().unstack(level=-1).reset_index()
df1.columns= ['Account length', 'False', 'True']

df1.plot(x='Account length', y='False', style='o');
plt.rcParams['figure.figsize'] = (20,11)
plt.ylabel('Number of customers not getting churned')

df1.plot(x='Account length', y='True', style='o')
plt.rcParams['figure.figsize'] = (20,11)
plt.ylabel('Number of customers getting churned')
# Out:
# Text(0, 0.5, 'Number of customers getting churned')

# %% [markdown]
# Observations:
#
#
#
# *   As we can see from the first plot that number of people not getting churned
#     increases till account length reaches the range of 90-120 days and then it
#     starts declining.
#
#
#
#
# *   Second plot tells us that number of people getting churned is highest when
#     account length reaches the range of 90 - 120 days. But the rate of people
#     getting churned is less than the rate at which people are not getting
#     churned in this range.
#
#
# *   There is a lot of volatility when account length is between 90 and 120 days.
#     We can provide some attractive offers/discounts to the customers when they
#     complete the milestone of 90 days. This will help in retaining more
#     customers and hence reducing the churning rate.

# %% [markdown]
# **Lets analyse the dataset when the account length is between 90 and 120 days**

# %%
telecom_df[(telecom_df['Account length'] >=90) & (telecom_df['Account length']<=120)].head(20)
# Out:
#    State  Account length  Area code International plan Voice mail plan  \
# 1     OH             107        415                 No             Yes
# 5     AL             118        510                Yes              No
# 8     LA             117        408                 No              No
# 13    MT              95        510                 No              No
# 17    VT              93        510                 No              No
# 23    SC             111        415                 No              No
# 40    GA              98        408                 No              No
# 48    ID             119        415                 No              No
# 49    WY              97        415                 No             Yes
# 53    UT              96        415                 No              No
# 61    CA             116        415                 No             Yes
# 67    MN             113        408                Yes              No
# ...

# %%
telecom_df[(telecom_df['Account length'] >=90) & (telecom_df['Account length']<=120)].tail(20)
# Out:
#      State  Account length  Area code International plan Voice mail plan  \
# 3267    MN             115        415                 No              No
# 3269    WV             117        510                Yes              No
# 3275    NY             120        510                 No             Yes
# 3281    UT             100        408                 No              No
# 3282    DC              99        415                 No             Yes
# 3283    AK              99        510                 No              No
# 3286    OH             106        415                 No             Yes
# 3291    MI             119        510                Yes             Yes
# 3292    IN             114        408                 No              No
# 3293    RI              95        408                 No              No
# 3294    MO             116        408                 No              No
# 3295    TN             110        415                 No              No
# ...

# %% [markdown]
# Observations:
#
# Reasons inferred from the above two dataset for people getting churned are -
#
#
#
# *   **Customer service calls**- If a customer makes 4 to 5 customer service
#     calls then they are more likely to get churned.
#
#
# *   **Day calling charge** - If the day calling charge is beyond $28
#      then the customer is more likely to get churned.
#
# *   **International and Voice mail plan** - People opting for any of these two
#     plans are also likely to get churned.

# %% [markdown]
# **Second Objective:** Exploit the 'Area code' column to see if we can get any insight regarding customer retention.

# %%
#To check the number of unique area codes we have in our dataset
list(telecom_df['Area code'].unique())
# Out:
# [415, 408, 510]

# %% [markdown]
# **So we have 3 unique area codes in our dataset. Now we will have a look on the churning rate across each area codes.**

# %%
df2 = telecom_df.groupby(['Area code', 'Churn'])['Churn'].count().unstack(level=-1).reset_index()
df2.columns = ['Area code', 'Not churned', 'Churned']
df2['Churning rate'] = (df2['Churned']/(df2['Not churned'] + df2['Churned'])) * 100
df2
# Out:
#    Area code  Not churned  Churned  Churning rate
# 0        408          716      122      14.558473
# 1        415         1419      236      14.259819
# 2        510          715      125      14.880952

# %% [markdown]
# **As we can see the churning rate across all the three area codes are approximately the same. We didn't get much insight. Lets do some analysis of day calling minutes and charges across all three area codes.**

# %%
#Obtain the trend of total number of calling minutes in a day across various area codes.
total_daycalling_minutes = telecom_df.groupby('Area code')['Total day minutes'].mean().reset_index().rename(columns={'Total day minutes':'Average day calling minutes of diff areas'})
print(total_daycalling_minutes)
# Out:
#    Area code  Average day calling minutes of diff areas
# 0        408                                 177.175418
# 1        415                                 181.592628
# 2        510                                 178.787619

# %%
type(total_daycalling_minutes)
# Out:
# pandas.core.frame.DataFrame

# %%
# Defining the values for x-axis, y-axis
# and from which dataframe the values are to be picked
plots = sns.barplot(x="Area code", y="Average day calling minutes of diff areas", data=total_daycalling_minutes)

# Defining the plot size
plt.rcParams['figure.figsize'] = (12, 8)

# Iterrating over the bars one-by-one
for bar in plots.patches:
    plots.annotate(format(bar.get_height(), '.2f'),
                   (bar.get_x() + bar.get_width() / 2,
                    bar.get_height()), ha='center', va='center',
                   size=8, xytext=(0, 15),
                   textcoords='offset points')

# %% [markdown]
# **Average day calling minutes across all the area codes are approximately the same.**

# %%
#Obtain the trend of average day call charge across various area codes.
total_daycharge = telecom_df.groupby('Area code')['Total day charge'].mean().reset_index().rename(columns={'Total day charge':'Average day call charges across diff areas'})
print(total_daycharge)
# Out:
#    Area code  Average day call charges across diff areas
# 0        408                                   30.120274
# 1        415                                   30.871335
# 2        510                                   30.394429

# %%
# Defining the values for x-axis, y-axis
# and from which dataframe the values are to be picked
plots = sns.barplot(x="Area code", y="Average day call charges across diff areas", data=total_daycharge)

# Defining the plot size
plt.rcParams['figure.figsize'] = (12, 8)

# Iterrating over the bars one-by-one
for bar in plots.patches:
    plots.annotate(format(bar.get_height(), '.2f'),
                   (bar.get_x() + bar.get_width() / 2,
                    bar.get_height()), ha='center', va='center',
                   size=8, xytext=(0, 8),
                   textcoords='offset points')

# %% [markdown]
# **Average day calling charges across all the area codes are approximately the same.
# As we are not getting any fruitful results from this column, it is not recommended to do further analysis and we can drop this column now.**

# %%
del telecom_df['Area code']

# %%
telecom_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3333 entries, 0 to 3332
# Data columns (total 19 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   State                   3333 non-null   object
#  1   Account length          3333 non-null   int64
#  2   International plan      3333 non-null   object
#  3   Voice mail plan         3333 non-null   object
#  4   Number vmail messages   3333 non-null   int64
#  5   Total day minutes       3333 non-null   float64
#  6   Total day calls         3333 non-null   int64
#  7   Total day charge        3333 non-null   float64
#  8   Total eve minutes       3333 non-null   float64
#  9   Total eve calls         3333 non-null   int64
#  10  Total eve charge        3333 non-null   float64
#  11  Total night minutes     3333 non-null   float64
#  12  Total night calls       3333 non-null   int64
#  13  Total night charge      3333 non-null   float64
# ...

# %% [markdown]
# **Third Objective: Exploit the 'Customer service calls' column to see if we can get more insight regarding customer retention.**

# %%
#As we know from our previous analysis that customers who make 4 or 5 customer service calls are more likely to get churned. So, first we will extract those customers who are making more than 3 such calls.
high_customer_service_calls = telecom_df[telecom_df['Customer service calls'] > 3]
high_customer_service_calls
# Out:
#      State  Account length  Area code International plan Voice mail plan  \
# 10      IN              65        415                 No              No
# 14      IA              62        415                 No              No
# 15      NY             161        415                 No              No
# 21      CO              77        408                 No              No
# 48      ID             119        415                 No              No
# ...    ...             ...        ...                ...             ...
# 3307    OK             172        408                 No              No
# 3309    VT             100        408                Yes              No
# 3320    GA             122        510                Yes              No
# 3322    MD              62        408                 No              No
# 3323    IN             117        415                 No              No
#
#       Number vmail messages  Total day minutes  Total day calls  \
# ...

# %%
high_customer_service_calls.head(10)
# Out:
#    State  Account length International plan Voice mail plan  \
# 10    IN              65                 No              No
# 14    IA              62                 No              No
# 15    NY             161                 No              No
# 21    CO              77                 No              No
# 48    ID             119                 No              No
# 54    WY              87                 No              No
# 69    TX             150                 No              No
# 77    NY             144                 No              No
# 86    IN              94                 No              No
# 97    AZ              99                 No              No
#
#     Number vmail messages  Total day minutes  Total day calls  \
# 10                      0              129.1              137
# 14                      0              120.7               70
# 15                      0              332.9               67
# ...

# %%
high_customer_service_calls.tail(10)
# Out:
#      State  Account length International plan Voice mail plan  \
# 3243    AR             113                Yes              No
# 3247    OK             146                 No              No
# 3280    AR              76                 No              No
# 3287    KS             170                 No             Yes
# 3304    IL              71                Yes              No
# 3307    OK             172                 No              No
# 3309    VT             100                Yes              No
# 3320    GA             122                Yes              No
# 3322    MD              62                 No              No
# 3323    IN             117                 No              No
#
#       Number vmail messages  Total day minutes  Total day calls  \
# 3243                      0              122.2              112
# 3247                      0              138.4              104
# 3280                      0              107.3              140
# ...

# %% [markdown]
# **As expected, customers making 4 or 5 service calls are more likely to get churned.**

# %%
#Lets extract the details of the top 10 states in which the number of customers who have made more than three customer service calls are highest.
high_customer_service_calls['State'].value_counts().head(10)
# Out:
# NY    10
# VT    10
# CO     9
# MD     9
# IN     8
# AR     8
# SC     8
# WV     8
# ID     7
# TX     7
# Name: State, dtype: int64

# %% [markdown]
# **Observations:**
#
#
# *   From above dataset we can see that New York and Vermont are two states where
#     ten customers are making more than three customer service calls.
#
#
# *   We should focus on these areas and provide them better infrastructure in
#     terms of technology and services.

# %%
# Lets visualize how the churning rate varies with number of customer service calls.
telecom_df.groupby(['Customer service calls','Churn'])['Churn'].count().unstack(level=-1).plot(kind = 'bar')
plt.rcParams['figure.figsize'] = (12, 8)
plt.ylabel('Number of people')
# Out:
# Text(0, 0.5, 'Number of people')

# %%
sns.barplot(x="Customer service calls", y ="Churn" , data = telecom_df)

# %% [markdown]
# **Observations:**
#
#
#
# *   Some of the customers have not even made any customer service calls and have
#     directly switched the operator.
#
#
# *   Also the customers who have made only one customer service call have high
#     churn rate which means their issues were not resolved at the first attempt.
#     Customer feedback is necessary in such circumstances and they should be
#     given an assurance that their issue will be resolved.

# %%
high_customer_service_calls.shape
# Out:
# (267, 20)

# %% [markdown]
# **We have a total of 267 customers who are making more than three customer service calls. This is about 8% of our total customers. We should try to reduce this percentage as much as possible.**

# %% [markdown]
# **Fourth Objective: Exploit the 'International plan' column to see if we can get more insight regarding customer retention.**

# %%
#First lets see how many customers have opted for International Plan
telecom_df['International plan'].value_counts()
# Out:
# No     3010
# Yes     323
# Name: International plan, dtype: int64

# %%
# Lets see the churning of those who have opted for international plan
df3 = telecom_df.groupby(['International plan','Churn'])['Churn'].count().unstack(level=-1).reset_index()
df3.columns = ['International plan', 'Not churned', 'Churned']
df3['Churning rate'] = (df3['Churned']/(df3['Not churned'] + df3['Churned'])) * 100
df3
# Out:
#   International plan  Not churned  Churned  Churning rate
# 0                 No         2664      346      11.495017
# 1                Yes          186      137      42.414861

# %% [markdown]
# **Almost 42% of people who have opted for international plan are getting churned.**

# %%
telecom_df[(telecom_df['International plan'] == 'Yes') & (telecom_df['Churn'] == True)].head(20)
# Out:
#     State  Account length  Area code International plan Voice mail plan  \
# 41     MD             135        408                Yes             Yes
# 115    ME              36        510                Yes             Yes
# 144    VT             117        408                Yes              No
# 198    ME             131        510                Yes             Yes
# 214    FL              70        510                Yes              No
# 230    MD              93        408                Yes              No
# 241    NV             137        415                Yes              No
# 258    KS              92        408                Yes              No
# 319    SD             128        510                Yes             Yes
# 354    MS              64        408                Yes              No
# 360    CO             159        408                Yes              No
# 372    CA             151        415                Yes              No
# ...

# %%
telecom_df[(telecom_df['International plan'] == 'Yes') & (telecom_df['Churn'] == True)].tail(20)
# Out:
#      State  Account length  Area code International plan Voice mail plan  \
# 2794    MT             137        408                Yes              No
# 2800    SD              52        510                Yes              No
# 2828    MS             123        415                Yes              No
# 2868    MA              17        415                Yes              No
# 2882    MI             178        408                Yes              No
# 2942    GA             117        415                Yes              No
# 2971    MI             148        415                Yes              No
# 2987    NY             131        408                Yes              No
# 2989    MI             108        408                Yes              No
# 3148    WA              60        415                Yes              No
# 3157    AR             127        415                Yes              No
# 3189    WA              76        510                Yes              No
# ...

# %% [markdown]
# **Observations:**
#
#
#
# *   From the above dataset we can see that most of the people are paying 3 to 5
#     dollars for 10 to 15 minutes of international call. We also know that
#     42% customers who opted for international plan are getting churned. So
#     we need a more better pricing strategy to lower the churning rate.

# %%
#To see the clear picture lets draw a bar chart 
df3.plot(kind = 'bar')

# %% [markdown]
# **Fifth Objective: Exploit the 'Voice mail plan' column to see if we can get more insight regarding customer retention.**

# %%
#First lets see how many customers have opted for Voice mail Plan
telecom_df['Voice mail plan'].value_counts()
# Out:
# No     2411
# Yes     922
# Name: Voice mail plan, dtype: int64

# %%
# Lets see the churning of those who have opted for voice mail plan
df4 = telecom_df.groupby(['Voice mail plan','Churn'])['Churn'].count().unstack(level=-1).reset_index()
df4.columns = ['Voice mail plan', 'Not churned', 'Churned']
df4['Churning rate'] = (df4['Churned']/(df4['Not churned'] + df4['Churned'])) * 100
df4
# Out:
#   Voice mail plan  Not churned  Churned  Churning rate
# 0              No         2008      403      16.715056
# 1             Yes          842       80       8.676790

# %%
df4.plot(kind = 'bar')
plt.rcParams['figure.figsize']=(12,8)

# %% [markdown]
# **A total of 922 customers opted for voice mail plan. Out of 922 about 80 customers i.e. 8.6 ~ 9% customers are getting churned. Churning rate is quite high. Voice mail services surely needs some upgradation.**

# %% [markdown]
# **Sixth Objective: Analyse the day call, minute and charge columns.**

# %%
# Comparison of day, evening and night call charges.

sns.histplot(telecom_df, x="Total day charge",label = 'Day', bins=50, alpha= 0.5, color= 'red')
sns.histplot(telecom_df, x="Total night charge", label = 'night', bins=50, alpha= 0.5, color= 'black')
sns.histplot(telecom_df, x="Total eve charge", label = 'evening', bins=50, alpha= 0.5, color= 'orange')

plt.xlabel("Day, night and evening charge")
plt.ylabel("Number of people")
plt.legend()

# %% [markdown]
# **We can clearly see that day calling charges are very high as compared to both evening and night calling charges.**

# %%
#Now lets compare the number of calls made during day, evening and night.
# Day vs Night calls
plt.hist(telecom_df['Total day calls'], 
         label='Total day calls',
         alpha=0.5)
  
plt.hist(telecom_df['Total night calls'], 
         label='Total night calls',
         alpha=0.5)
plt.rcParams["figure.figsize"] = (10,7)
plt.legend()
plt.xlabel('Day & Night Calls',fontsize=12)
plt.ylabel('Frequency',fontsize=12)
plt.title('Histogram Of Total Day Calls vs Total Night Calls',fontsize=17)
# Out:
# Text(0.5, 1.0, 'Histogram Of Total Day Calls vs Total Night Calls')

# %%
# Day vs Evening calls
plt.hist(telecom_df['Total day calls'], 
         label='Total day calls',
         alpha=0.5)
  
plt.hist(telecom_df['Total eve calls'], 
         label='Total eve calls',
         alpha=0.5)

plt.rcParams["figure.figsize"] = (10,7)
plt.legend()
plt.xlabel('Day & eve Calls',fontsize=12)
plt.ylabel('Frequency',fontsize=12)
plt.title('Histogram Of Total Day Calls vs Total eve Calls',fontsize=17)
# Out:
# Text(0.5, 1.0, 'Histogram Of Total Day Calls vs Total eve Calls')

# %% [markdown]
# **From the above two histograms we can see that a total of 100 calls are made on average during day, evening and night. **

# %%
#Lets make a scatterplot to see how churning varies with day calling charge and day calling minutes.
sns.scatterplot(x='Total day minutes' , y = 'Total day charge', hue = 'Churn',data =telecom_df)
plt.rcParams['figure.figsize']=(20,11)

# %% [markdown]
# **It is clearly evident from the above scatterplot that churning rate increases as total day minute and day charge increases. Most of the customers who have total day calling minutes more than 250 minutes and total day charge more than $40 are churned.**

# %%
# Lets see the effect of both customer service calls and day charges on the churning.
_,ax = plt.subplots(1, 2, figsize= (16, 6))
sns.scatterplot(x='Total day minutes' , y = 'Total day charge', hue = 'Churn',data =telecom_df, ax=ax[0])
sns.scatterplot(x='Customer service calls', y = 'Total day charge',hue = 'Churn',data =telecom_df, ax=ax[1])

# %% [markdown]
# **From the right hand side plot we can clearly see that when the customer service calls are less than 3 then the total day charge has the predominant effect on churning and as the customer service calls increases and goes beyond 4 it replaces total day charge and has the predominant effect on churning.**

# %%
# Lets draw the scatterplot for evening and night charges as well.
sns.scatterplot(x='Total eve minutes' , y = 'Total eve charge', hue = 'Churn',data =telecom_df)

# %%
sns.scatterplot(x='Total night minutes' , y = 'Total night charge', hue = 'Churn',data =telecom_df)

# %% [markdown]
# **Seventh Objective: Plot a heatmap to get a clearer picture.**

# %%
# We will two new columns (Total local calls and Total charges) to our existing dataset.
total_localcalls= telecom_df["Total day calls"] + telecom_df["Total night calls"] + telecom_df["Total eve calls"]  
telecom_df["Total Local Calls"] = total_localcalls

total_charge_col = telecom_df["Total day charge"] + telecom_df["Total night charge"] + telecom_df["Total eve charge"] + telecom_df["Total intl charge"]
telecom_df["Total Charges"] = total_charge_col

# %%
telecom_df.head(5)
# Out:
#   State  Account length  Area code International plan Voice mail plan  \
# 0    KS             128        415                 No             Yes
# 1    OH             107        415                 No             Yes
# 2    NJ             137        415                 No              No
# 3    OH              84        408                Yes              No
# 4    OK              75        415                Yes              No
#
#    Number vmail messages  Total day minutes  Total day calls  \
# 0                     25              265.1              110
# 1                     26              161.6              123
# 2                      0              243.4              114
# 3                      0              299.4               71
# 4                      0              166.7              113
#
#    Total day charge  Total eve minutes  ...  Total night minutes  \
# 0             45.07              197.4  ...                244.7
# ...

# %%
corr_df= telecom_df.corr()

plt.rcParams['figure.figsize'] = (20,11)

# %%
sns.heatmap(corr_df, mask=np.zeros_like(corr_df, dtype=np.bool),vmin=-1, cmap='coolwarm', annot=True,linewidths=1)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: DeprecationWarning: `np.bool` is a deprecated alias for the builtin `bool`. To silence this warning, use `bool` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.bool_` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   """Entry point for launching an IPython kernel.

# %% [markdown]
# **Observations:**
#
# *   90% of total local calls are day calls.
# *   90% of total charge comes from day charge.
#
# *   Total day charge and customer service calls have highest contribution in churning of a customer.

# %% [markdown]
# **Eight Objective: Do the state wise analysis of the dataset.**

# %%
telecom_df['State'].value_counts()
# Out:
# WV    106
# MN     84
# NY     83
# AL     80
# WI     78
# OH     78
# OR     78
# WY     77
# VA     77
# CT     74
# MI     73
# ID     73
# VT     73
# TX     72
# UT     72
# IN     71
# MD     70
# KS     70
# NC     68
# NJ     68
# MT     68
# CO     66
# NV     66
# WA     66
# RI     65
# MA     65
# MS     65
# AZ     64
# FL     63
# MO     63
# NM     62
# ME     62
# ND     62
# NE     61
# OK     61
# DE     61
# SC     60
# SD     60
# KY     59
# IL     58
# NH     56
# AR     55
# GA     54
# DC     54
# HI     53
# TN     53
# AK     52
# LA     51
# PA     45
# IA     44
# CA     34
# Name: State, dtype: int64

# %%
# Visualize the number of subscribers across all the states.
plt.rcParams['figure.figsize'] = (20, 8)
p = sns.countplot(x='State', data=telecom_df)
p.set_title("Number of customers in each state")
p.set_xlabel("State", fontsize = 15)
p.set_ylabel("Number of customers in state", fontsize = 15)
# Out:
# Text(0, 0.5, 'Number of customers in state')

# %% [markdown]
# **West Virginia has the highest number of subscribers and California has the lowest number of subscribers. **

# %%
states_with_highest_subscribers=telecom_df['State'].value_counts().head(5)   #gives series of first 5 states with count

 #plotting bar graph
plot = states_with_highest_subscribers.plot.bar(figsize=(12, 8))     

plt.title('States with highest number of subscribers')   #setting title 
#setting x and y label
plt.xlabel('Subscribers')     
plt.ylabel('States')
# Out:
# Text(0, 0.5, 'States')

# %%
#Find the churning rate across each states.
df5 = telecom_df.groupby(['State','Churn'])['Churn'].count().unstack(level=-1).reset_index()

df5.columns= ['state', 'False', 'True']
df5['Churning rate'] =  np.round((df5['True'] /(df5['True']+ df5['False']))*100,2)
df5.sort_values('Churning rate')
# Out:
#    state  False  True  Churning rate
# 11    HI     50     3           5.66
# 0     AK     49     3           5.77
# 3     AZ     60     4           6.25
# 45    VA     72     5           6.49
# 12    IA     41     3           6.82
# 18    LA     47     4           7.84
# 29    NE     56     5           8.20
# 14    IL     53     5           8.62
# 48    WI     71     7           8.97
# 39    RI     59     6           9.23
# 7     DC     49     5           9.26
# 42    TN     48     5           9.43
# 49    WV     96    10           9.43
# 32    NM     56     6           9.68
# 28    ND     56     6           9.68
# 1     AL     72     8          10.00
# 46    VT     65     8          10.96
# 24    MO     56     7          11.11
# 50    WY     68     9          11.69
# 13    ID     64     9          12.33
# 15    IN     62     9          12.68
# 9     FL     55     8          12.70
# 35    OH     68    10          12.82
# 41    SD     52     8          13.33
# ...

# %%
#Top 5 states with highest churning rate
df5.sort_values('Churning rate').tail(5)
# Out:
#    state  False  True  Churning rate
# 40    SC     46    14          23.33
# 20    MD     53    17          24.29
# 43    TX     54    18          25.00
# 31    NJ     50    18          26.47
# 4     CA     25     9          26.47

# %% [markdown]
# **We need to focus on all these areas where the churning rate is high.**

# %%
#Top 5 states with lowest churning rate
df5.sort_values('Churning rate').head(5)
# Out:
#    state  False  True  Churning rate
# 11    HI     50     3           5.66
# 0     AK     49     3           5.77
# 3     AZ     60     4           6.25
# 45    VA     72     5           6.49
# 12    IA     41     3           6.82

# %%
# State wise churners and non churners.
telecom_df.groupby(['State','Churn'])['Churn'].count().unstack(level=-1).plot(kind='bar')

# %%
cols = ["Total day charge", "Total eve charge","Total night charge", "Customer service calls", "Churn"] 
pairplot_feature = telecom_df[cols]
sns.pairplot(pairplot_feature, hue = "Churn")

# %% [markdown]
# **From above we can clearly observe that churn is dependent on the following factors:**
#
# *  Churn rate mostly depends upon the 'Day charge' and 'Customer Service calls'.
# *   In 'eve charge' vs 'customer service calls' and 'night charge' vs 'customer service calls'. We can easily analyse that churn is independent of eve and night charge.

# %% [markdown]
# **Outlier analysis**

# %% [markdown]
# We can draw the box plot for all the continuous columns to see the outlier in each column in our dataframe

# %%
#All continous variables in cont_col
cont_col = telecom_df.columns[(telecom_df.dtypes=="float64")|(telecom_df.dtypes=="int64")].tolist()
print(cont_col)

#All categorical var in cat_col
cat_col = telecom_df.select_dtypes(exclude=np.number).columns.tolist()
print(cat_col)

#Plotting Box Plots
for i in cont_col:
    plt.figure()
    plt.clf()   #Clearing the figure
    sns.boxplot(telecom_df[i],palette="deep")
    plt.title(f"{i} box plot")
    plt.show()
# Out:
# ['Account length', 'Area code', 'Number vmail messages', 'Total day minutes', 'Total day calls', 'Total day charge', 'Total eve minutes', 'Total eve calls', 'Total eve charge', 'Total night minutes', 'Total night calls', 'Total night charge', 'Total intl minutes', 'Total intl calls', 'Total intl charge', 'Customer service calls', 'Total Local Calls', 'Total Charges']
# ['State', 'International plan', 'Voice mail plan', 'Churn']
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# ...

# %% [markdown]
# From above box plots we can observe there are outliers in all columns so we have to start treating the outliers.

# %%
#Treating Out Liers and Converting them to nan
for i in cont_col:
    q3, q1 = np.percentile(telecom_df.loc[:,i], [75 ,25])
    iqr = q3 - q1
    minn = q1 - (iqr*1.5)
    maxx = q3 + (iqr*1.5)
    #Converting to nan
    telecom_df.loc[telecom_df.loc[:,i] < minn,i] = np.nan
    telecom_df.loc[telecom_df.loc[:,i] > maxx,i] = np.nan
    print('{var} -- {X} Missing'.format(var = i, X = (telecom_df.loc[:,i].isnull().sum())))
# Out:
# Account length -- 18 Missing
# Area code -- 0 Missing
# Number vmail messages -- 1 Missing
# Total day minutes -- 25 Missing
# Total day calls -- 23 Missing
# Total day charge -- 25 Missing
# Total eve minutes -- 24 Missing
# Total eve calls -- 20 Missing
# Total eve charge -- 24 Missing
# Total night minutes -- 30 Missing
# Total night calls -- 22 Missing
# Total night charge -- 30 Missing
# Total intl minutes -- 46 Missing
# Total intl calls -- 78 Missing
# Total intl charge -- 49 Missing
# Customer service calls -- 267 Missing
# Total Local Calls -- 16 Missing
# Total Charges -- 27 Missing

# %%
telecom_df['Account length'].mean()
# Out:
# 100.43046757164404

# %%
telecom_df.mean()
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   """Entry point for launching an IPython kernel.
# Account length            100.430468
# Area code                 437.182418
# Number vmail messages       8.086134
# Total day minutes         179.946252
# Total day calls           100.587613
# Total day charge           30.591403
# Total eve minutes         201.176065
# Total eve calls           100.164503
# Total eve charge           17.100178
# Total night minutes       200.825219
# Total night calls          99.973422
# Total night charge          9.037221
# Total intl minutes         10.293368
# Total intl calls            4.279263
# Total intl charge           2.777948
# Customer service calls      1.300065
# Churn                       0.144914
# ...

# %%
#filling null values with mean
for i in cont_col:
  print(i)
  mean = telecom_df[i].mean()
  print(mean)
  telecom_df[i]=  telecom_df[i].fillna(mean)
# Out:
# Account length
# 100.43046757164404
# Area code
# 437.18241824182417
# Number vmail messages
# 8.086134453781513
# Total day minutes
# 179.94625151148728
# Total day calls
# 100.58761329305136
# Total day charge
# 30.591402660217653
# Total eve minutes
# 201.17606527651859
# Total eve calls
# 100.16450347117416
# Total eve charge
# 17.10017830160169
# Total night minutes
# 200.82521949742656
# Total night calls
# 99.9734219269103
# Total night charge
# 9.037220708446867
# Total intl minutes
# 10.293367812595072
# Total intl calls
# 4.27926267281106
# Total intl charge
# 2.777947624847747
# Customer service calls
# 1.3000652315720809
# Total Local Calls
# 300.76967138981007
# Total Charges
# 59.481306715063525

# %%
telecom_df.iloc[3320:,:]
# Out:
#      State  Account length  Area code International plan Voice mail plan  \
# 3320    GA           122.0      510.0                Yes              No
# 3321    VT            60.0      415.0                 No              No
# 3322    MD            62.0      408.0                 No              No
# 3323    IN           117.0      415.0                 No              No
# 3324    WV           159.0      415.0                 No              No
# 3325    OH            78.0      408.0                 No              No
# 3326    OH            96.0      415.0                 No              No
# 3327    SC            79.0      415.0                 No              No
# 3328    AZ           192.0      415.0                 No             Yes
# 3329    WV            68.0      415.0                 No              No
# 3330    RI            28.0      510.0                 No              No
# 3331    CT           184.0      510.0                Yes              No
# ...

# %% [markdown]
# **Insights:**
#
#
#
# *   Main insights from account length analysis-
#
#       *   Number of people not getting churned increases till account length reaches the range of 90-120 days and then it starts declining.
#
#       *  Number of people getting churned is highest when account length reaches the range of 90 - 120 days. But the rate of people getting churned is less than the rate at which people are not getting churned in this range.
#
# *   Main insights from Customer service calls -
#
#       *   Some of the customers have not even made any customer service calls and have directly switched the operator.
#
#       *   Also the customers who have made only one customer service call have high churn rate which means their issues were not resolved at the first attempt.
#
#       *   Customer making more than 3 customer service calls is most likely to get churned.
#
#       *   8% of our total customers are making more than 3 customer service calls.
#
#       *   New York, Vermont, Colorado, Maryland are few of the states from where a lot of customers make more than 3 customer service calls.
#
#
# *   Main insights from International plan -
#
#       *   42% of customers who opted for international plan are getting churned.
#
#       *   Most of the people are paying 3 to 5 dollars for 10 to 15 minutes of international call.
#
#
#
# *   8 - 9% of customers who opted for voice mail plans are getting churned.
#
#
#
#
#
#
# *   Main insight from day, evening and night calls and charges -
#
#       *   A total of 100 calls are made on average during day, evening and night.
#
#       *   Even though the same number of calls are made on average, day calling charges are significantly higher as compared to evening and night charges.
#
#       *   90% of total local charge comes from day calling charges.
#
#       *    Churning rate increases as total day minute and day charge increases. Most of the customers who have total day calling minutes more than 250 minutes and total day charge more than $40 are churned.
#
#       *   When the customer service calls are less than 3 then the total day charge has the predominant effect on churning and as the customer service calls increases and goes beyond 4 it replaces total day charge and has the predominant effect on churning.
#
#
# *   Main insights from state wise analysis -
#
#     *   West Virginia, Minnesota and New York are the top 3 state with highest number of subscribers.
#
#    *   California, Indiana and Pennsylvania are the states top 3 states having lowest number of subscribers.
#
#    *   California and New Jersey have the highest churning rate.
#
#    *   New York and Texas have the highest number of churners.

# %% [markdown]
# **Recommendations -**
#
#
#
# *   Need to increase marketing budget and create marketing campaigns in states having low number of subscribers.
#
# *   Provide attractive offers and discounts to customers when they complete the milestone of 90 days. This will help in retaining more customers and hence reducing the churning rate.
#
#
#
# *   Need to resolve the issue faced by any customer at first attempt i.e. during the first customer service call. Customer feedback is necessary in such circumstances and they should be given an assurance that their issue will be resolved.
#
# *   Customers opting for international plan tends to churn more. Different pricing strategy with better services will help retaining the customers.
#
#
#
# *   Customers with total day calling charge more than 40 are more likely to get churned. Providing discounts when day calling bill goes beyond $40 will help retaining customers.
